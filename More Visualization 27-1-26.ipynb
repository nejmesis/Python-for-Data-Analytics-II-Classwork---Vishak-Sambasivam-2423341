# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\User\Downloads\Piece_Dim - Piece_Dim.csv")

# %%
display(df.head(5))
# Out:
#   Item_No  Length  Width  Height Operator
# 0  Item-1  102.67  49.53   19.69     Op-1
# 1  Item-2  102.50  51.42   19.63     Op-1
# 2  Item-3   95.37  52.25   21.51     Op-1
# 3  Item-4   94.77  49.24   18.60     Op-1
# 4  Item-5  104.26  47.90   19.46     Op-1

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Item_No   50 non-null     object
#  1   Length    50 non-null     float64
#  2   Width     50 non-null     float64
#  3   Height    50 non-null     float64
#  4   Operator  50 non-null     object
# dtypes: float64(3), object(2)
# memory usage: 2.1+ KB
# None

# %%
sns.histplot(data=df, x='Length', hue='Operator')
# Out:
# <Axes: xlabel='Length', ylabel='Count'>

# %%
sns.displot(data=df, x="Length", col='Operator')

# %%
fig, ax = plt.subplots(figsize=(15, 5))
sns.lineplot(data=df, x='Length', y='Width', ax=ax)
plt.show()

# %%
sns.displot(data=df, x="Length", rug=True, kind='ecdf')

# %%
sns.displot(data=df, x="Length", kde=True, rug=True)

# %%
sns.displot(data=df, x='Length', y='Width')

# %%
sns.displot(data=df, x='Length', y='Width', kind='kde')

# %%
sns.catplot(data=df, x='Operator', y='Length')
