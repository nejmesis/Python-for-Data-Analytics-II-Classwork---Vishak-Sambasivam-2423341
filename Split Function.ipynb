# %%
import pandas as pd
import numpy as np

# %%
nba = pd.read_csv(r"C:\Users\User\Downloads\SBA-class-activity-main\nba.csv")

# %%
nba[['Feet', 'Inch']] = nba['Height'].str.split('-', expand = True)

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary feet inch Feet Inch
# 0        Villanova   4556983.0    6    7    6    7
# 1       Fenerbahce  18700000.0    6    5    6    5
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    object
#  2   Position  584 non-null    object
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   578 non-null    object
#  6   Salary    488 non-null    float64
#  7   feet      585 non-null    object
#  8   inch      585 non-null    object
#  9   Feet      585 non-null    float64
#  10  Inch      585 non-null    float64
# dtypes: float64(4), object(7)
# memory usage: 51.0+ KB

# %%
nba[['Feet', 'Inch']] = nba[['Feet', 'Inch']].apply(pd.to_numeric)

# %%
nba.Feet = nba.Feet.astype(float)

# %%
nba['Height (cm)'] = nba['Feet']*30.48+nba['Inch']*2.54

# %%
# [] -> list and [[]] -> dataframe

# %%
nba['College'].dropna(inplace = True)

# %%
nba['College'].isna().value_counts()
# Out:
# College
# False    578
# True      14
# Name: count, dtype: int64

# %%
nba['College'].unique()
# Out:
# array(['Villanova', 'Fenerbahce', 'Michigan', 'Elan Chalon', 'Maryland',
#        'Florida State', 'Duke', 'Washington State', 'Virginia',
#        'Penn State', 'Lipscomb', 'Marquette', "St. Mary's", 'Washington',
#        nan, 'Southern California', 'Oklahoma', 'Nebraska', 'Syracuse',
#        'California', 'Alabama', 'Florida', 'Vanderbilt', 'Kansas',
#        'Cajasol Sevilla', 'Oregon', 'John A. Logan', 'Arkansas',
#        'Colorado', 'Texas A&M', 'Princeton HS (OH)', 'Houston', 'Georgia',
#        'North Carolina', 'Baylor', 'Louisiana State',
#        'North Carolina State', 'Miami', 'UCLA', 'Illawarra',
#        'Connecticut', 'Michigan State', 'Butler', 'Texas', 'Asvel',
#        'Nevada', 'FC Barcelona', 'Strasbourg IG', 'Kentucky',
#        'Louisville', 'Auburn', 'West Virginia', 'South Carolina Upstate',
#        'Illinois', 'Radford', 'Tennessee', 'Austin Peay', 'Arizona',
#        'Eastern Michigan', 'Utah State', 'Murcia', 'Iowa State',
# ...

# %%
nba.drop('Height (cm)', axis = 1)
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary feet inch  Feet  Inch
# 0        Villanova   4556983.0    6    7   6.0   7.0
# 1       Fenerbahce  18700000.0    6    5   6.0   5.0
# ...

# %%
nba['College'] = nba['College'].replace(np.nan, 'Unknown')

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...
