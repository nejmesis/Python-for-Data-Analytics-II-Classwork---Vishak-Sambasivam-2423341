# %% [markdown]
# # Dataframe and Series

# %%
# Dataframe -> 2-dimensional array consisting of rows and columns. 
# Series -> 1-dimensional array holding one type of data

# %%
# method -> function that belongs to an object. 
# attribute -> characteristic associated with an object.

# %%
### DO NOT USE () FOR ATTRIBUTES.
