# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Creating a dataframe

# Fist create a dictionary of lists.

data = {'Anime': ['One Piece', 'Bleach', 'Naruto'],
       'MC': ['Luffy', 'Ichigo', 'Naruto'],
       'Year': [1999, 2002, 2003]} 

# Using pandas' dataframe function, create a df

df = pd.DataFrame(data)

# %%
df
# Out:
#        Anime      MC  Year
# 0  One Piece   Luffy  1999
# 1     Bleach  Ichigo  2002
# 2     Naruto  Naruto  2003

# %%
df.sort_values(by = 'MC')
# Out:
#        Anime      MC  Year
# 1     Bleach  Ichigo  2002
# 0  One Piece   Luffy  1999
# 2     Naruto  Naruto  2003

# %%
df.sort_index(ascending = False)
# Out:
#        Anime      MC  Year
# 2     Naruto  Naruto  2003
# 1     Bleach  Ichigo  2002
# 0  One Piece   Luffy  1999

# %%
df.groupby(['MC'])['Year'].mean()
# Out:
# MC
# Ichigo    2002.0
# Luffy     1999.0
# Naruto    2003.0
# Name: Year, dtype: float64

# %%
nba = pd.read_csv(r"C:\Users\User\Downloads\SBA-class-activity-main\nba.csv")

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.shape
# Out:
# (592, 7)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    object
#  2   Position  584 non-null    object
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   578 non-null    object
#  6   Salary    488 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 32.5+ KB

# %%
nba.describe()
# Out:
#            Weight        Salary
# count  584.000000  4.880000e+02
# mean   214.763699  9.218978e+06
# std     23.460612  1.131927e+07
# min    160.000000  5.088910e+05
# 25%    198.000000  1.980599e+06
# 50%    215.000000  4.018638e+06
# 75%    230.000000  1.169694e+07
# max    290.000000  5.191562e+07

# %%
nba.dropna(inplace = True)

# %%
nba.groupby('Name')['Salary'].mean().round(2)
# Out:
# Name
# AJ Green            1901769.0
# AJ Griffin          3712920.0
# Aaron Gordon       22266182.0
# Aaron Holiday       2346614.0
# Aaron Nesmith       5634257.0
#                       ...
# Zach Collins        7700000.0
# Zach LaVine        40064220.0
# Zeke Nnaji          4306281.0
# Ziaire Williams     4810200.0
# Zion Williamson    34005250.0
# Name: Salary, Length: 475, dtype: float64

# %%
name = pd.Series(nba['Name'])

# %%
name
# Out:
# 0             Saddiq Bey
# 1      Bogdan Bogdanovic
# 2            Kobe Bufkin
# 3           Clint Capela
# 4         Bruno Fernando
#              ...
# 585       Eugene Omoruyi
# 586         Jordan Poole
# 587         Ryan Rollins
# 588        Landry Shamet
# 590         Delon Wright
# Name: Name, Length: 475, dtype: object

# %%
pokemon_series = pd.read_csv(r"C:\Users\User\Downloads\SBA-class-activity-main\pokemon.csv", usecols = ['Name']).squeeze('columns')

# %%
pokemon_series
# Out:
# 0          Bulbasaur
# 1            Ivysaur
# 2           Venusaur
# 3         Charmander
# 4         Charmeleon
#             ...
# 1005    Iron Valiant
# 1006        Koraidon
# 1007        Miraidon
# 1008    Walking Wake
# 1009     Iron Leaves
# Name: Name, Length: 1010, dtype: object

# %%
len(pokemon_series)
# Out:
# 1010

# %%
pd.Series(data['Anime'])
# Out:
# 0    One Piece
# 1       Bleach
# 2       Naruto
# dtype: object

# %%
salary = pd.Series(nba['Salary'])

# %%
salary.sum()
# Out:
# 4486546210.0

# %%
salary.product()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\numpy\core\_methods.py:53: RuntimeWarning: overflow encountered in reduce
#   return umr_prod(a, axis, dtype, out, keepdims, initial, where)
# inf

# %%
salary.std()
# Out:
# 11389038.458002947

# %%
salary.size
# Out:
# 475

# %%
salary.values
# Out:
# array([ 4556983., 18700000.,  4094244., 20616000.,  2581522.,   508891.,
#         3712920.,  1119563., 20089286.,  2925360.,   559782.,  2000000.,
#         3196448.,  6802950., 18214000.,  8109063., 40064220.,  2019706.,
#         2165000., 22500000., 31830357.,   559782.,  1927896., 10000000.,
#         2413304., 36016200.,  4037277.,   559782., 32600060.,  1119563.,
#        18357143.,  2165000., 21700000.,   559782.,  3089460., 20357143.,
#        13932008., 25679348.,  9500000.,  2210040., 37893408.,  2240160.,
#         2019706.,  2966040.,   559782.,   559782., 10900635.,   559782.,
#         4570080.,  7921300., 31500000.,  3047880.,  7560000.,  1719864.,
#        10880364.,  2528233., 23205221.,  1836096.,  3908160., 20465117.,
#         6190476.,  9460000.,  2528233., 28600000.,  6481482.,  3360000.,
#         1927896., 40064220.,  1600000.,   559782.,  2019706.,  3350760.,
#        18518519., 11111111.,  9835881., 20000000.,   559782., 34005250.,
# ...

# %%
salary.dtypes
# Out:
# dtype('float64')

# %%
salary.is_unique
# Out:
# False

# %%
type(salary.values)
# Out:
# numpy.ndarray

# %%
pd.Series(index = nba['Name'], data = nba['Salary'])
# Out:
# Name
# Saddiq Bey          NaN
# Bogdan Bogdanovic   NaN
# Kobe Bufkin         NaN
# Clint Capela        NaN
# Bruno Fernando      NaN
#                      ..
# Eugene Omoruyi      NaN
# Jordan Poole        NaN
# Ryan Rollins        NaN
# Landry Shamet       NaN
# Delon Wright        NaN
# Name: Salary, Length: 475, dtype: float64

# %%
nba.sort_values(by = 'Name', ascending = False)
# Out:
#                 Name                  Team Position Height  Weight  \
# 370  Zion Williamson  New Orleans Pelicans        F    6-6   284.0
# 291  Ziaire Williams     Memphis Grizzlies        F    6-9   185.0
# 149       Zeke Nnaji        Denver Nuggets      F-C    6-9   240.0
# 83       Zach LaVine         Chicago Bulls        G    6-5   200.0
# 515     Zach Collins     San Antonio Spurs      F-C   6-11   250.0
# ..               ...                   ...      ...    ...     ...
# 222    Aaron Nesmith        Indiana Pacers      G-F    6-5   215.0
# 198    Aaron Holiday       Houston Rockets        G    6-0   185.0
# 141     Aaron Gordon        Denver Nuggets        F    6-8   235.0
# 6         AJ Griffin         Atlanta Hawks        F    6-6   220.0
# 324         AJ Green       Milwaukee Bucks        G    6-5   190.0
#
#            College      Salary
# 370           Duke  34005250.0
# 291       Stanford   4810200.0
# 149        Arizona   4306281.0
# 83            UCLA  40064220.0
# ...

# %%
nba[['Feet', 'Inch']] = nba['Height'].str.split('-', expand = True)

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary Feet Inch
# 0        Villanova   4556983.0    6    7
# 1       Fenerbahce  18700000.0    6    5
# ...

# %%
nba[['Feet', 'Inch']] = nba[['Feet', 'Inch']].apply(pd.to_numeric)

# %%
nba['Height in CM'] = nba['Feet'] * 30.48 + nba['Inch'] * 2.54

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary  Feet  Inch  Height in CM
# 0        Villanova   4556983.0     6     7        200.66
# ...

# %%
nba.drop('Height in CM', axis = 1)
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary  Feet  Inch
# 0        Villanova   4556983.0     6     7
# 1       Fenerbahce  18700000.0     6     5
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 475 entries, 0 to 590
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          475 non-null    object
#  1   Team          475 non-null    object
#  2   Position      475 non-null    object
#  3   Height        475 non-null    object
#  4   Weight        475 non-null    float64
#  5   College       475 non-null    object
#  6   Salary        475 non-null    float64
#  7   Feet          475 non-null    int64
#  8   Inch          475 non-null    int64
#  9   Height in CM  475 non-null    float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 57.0+ KB

# %%
sns.countplot(data = nba, x = 'Team')
# Out:
# <Axes: xlabel='Team', ylabel='count'>

# %%
nba['Height in CM'].plot(kind = 'hist', figsize = (12, 6), color = 'blue', grid = False)
# Out:
# <Axes: ylabel='Frequency'>
