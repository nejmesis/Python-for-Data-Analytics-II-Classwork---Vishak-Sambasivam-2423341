# %%
import pandas as pd
import numpy as np

# %%
ice_cream = ['strawberry', 'chocolate', 'vanilla', 'tutty fruity']

# %%
pd.Series(ice_cream)
# Out:
# 0      strawberry
# 1       chocolate
# 2         vanilla
# 3    tutty fruity
# dtype: object

# %%
price = [10, 20, 5, 30]

# %%
pd.Series(price)
# Out:
# 0    10
# 1    20
# 2     5
# 3    30
# dtype: int64

# %%
height = [168.5, 171.4, 178.9, 180]

# %%
pd.Series(height)
# Out:
# 0    168.5
# 1    171.4
# 2    178.9
# 3    180.0
# dtype: float64

# %%
sushi = {
    'salmon': 400,
    'tuna': 300,
    'eel': 100
}

# %%
pd.Series(sushi)
# Out:
# salmon    400
# tuna      300
# eel       100
# dtype: int64

# %%
lottery = ([78359021, 934870839, 983741280, 382930295])

# %%
lottery = pd.Series([783659021, 934870839, 983741280, 382930295])

# %%
lottery
# Out:
# 0    783659021
# 1    934870839
# 2    983741280
# 3    382930295
# dtype: int64

# %%
lottery.sum()
# Out:
# 3085201435

# %%
lottery.dtypes
# Out:
# dtype('int64')

# %%
price = pd.Series([10, 20, 5, 30])

# %%
price.sum()
# Out:
# 65

# %%
price.product()
# Out:
# 30000

# %%
price.std()
# Out:
# 11.086778913041726

# %%
adj = pd.Series(['beautiful', 'smart', 'intelligent', 'handsome', 'smart'])

# %%
adj
# Out:
# 0      beautiful
# 1          smart
# 2    intelligent
# 3       handsome
# 4          smart
# dtype: object

# %%
adj.size
# Out:
# 5

# %%
# We do not put () for attributes.

# %%
adj.values
# Out:
# array(['beautiful', 'smart', 'intelligent', 'handsome', 'smart'],
#       dtype=object)

# %%
adj.is_unique
# Out:
# False

# %%
type(adj.values)
# Out:
# numpy.ndarray

# %%
weekdays = ['Mon', 'Tue', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun']

# %%
fruit = ['apple', 'banana', 'guava', 'pommegranete', 'watermelon', 'pineapple', 'orange']

# %%
pd.Series(fruit, weekdays) # pd.Series(index, data)
# Out:
# Mon             apple
# Tue            banana
# Wed             guava
# Thurs    pommegranete
# Fri        watermelon
# Sat         pineapple
# Sun            orange
# dtype: object
